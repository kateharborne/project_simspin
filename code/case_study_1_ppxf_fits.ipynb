# %% [markdown]
# # Case Study 1 - fitting spectral data cubes with pPXF
#
# If you do not already have pPXF installed, you can do so with `pip install ppxf`.
# The files produced in this notebook are then used for comparison with the kinematic SimSpin files produced in the R code files run previously.

# %%
import numpy as np
from astropy.io import fits
from astropy.coordinates import Angle
import matplotlib.pyplot as plt
from scipy.stats import scoreatpercentile
from scipy import ndimage,signal
import glob
import os
import sys

from matplotlib.ticker import MultipleLocator
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as ticker

from ppxf.ppxf import ppxf, rebin
import ppxf.ppxf_util as util
from ppxf import miles_util as lib

import threading
from argparse import ArgumentParser

c = 299792.458 # speed of light in km/s

# %%
#### VARIABLES ####
root_in            = "/cubes/"
root_out           = "/cubes/ppxf_output/"
template_loc       = "/data/EMILES_PADOVA_CH/Ech1.30*.fits"

file_name_list     = ["disk_EMILES_spectral_fwhm0_lowz",
                      "bulge_EMILES_spectral_fwhm0_lowz",
                      "old_bulge_EMILES_spectral_fwhm0_lowz",
                      "disk_BC03hr_spectral_fwhm0_lowz",
                      "bulge_BC03hr_spectral_fwhm0_lowz",
                      "old_bulge_BC03hr_spectral_fwhm0_lowz"]
folder_list        = ["fwhm0_lowz/disk_EMILES/",
                      "fwhm0_lowz/bulge_EMILES/",
                      "fwhm0_lowz/old_bulge_EMILES/",
                      "fwhm0_lowz/disk_BC03hr/",
                      "fwhm0_lowz/bulge_BC03hr/",
                      "fwhm0_lowz/old_bulge_BC03hr/"]

redshift           = 0.0144
telescope_FWHM_list= [0, 0, 0, 0, 0, 0]
template_FWHM_list = [2.51, 2.51, 2.51, 3, 3, 3]
n_mom              = 4
plot               = True

# %%
for i in range(1,3):
    
    folder = folder_list[i]
    template_FWHM = template_FWHM_list[i]
    file_name = file_name_list[i]
    telescope_FWHM = telescope_FWHM_list[i]
    FWHM_temp = 2.51
    z = redshift
        
    #### COMPUTATION based on variables ####
    if telescope_FWHM <= template_FWHM:
        FWHM_gal = (template_FWHM * (1 + z)) # Angstroms (resolution for this "observed" template)
    else:
        FWHM_gal = telescope_FWHM

    file_root = f"{root_in}{folder}"
    ppxf_out_root = f"{root_out}{folder}"
    #########################################

    inputFileExists = os.path.exists(f"{file_root}{file_name}.FITS")
    outputDirectoryExists = os.path.exists(ppxf_out_root)

    if not inputFileExists or not outputDirectoryExists:
        print("\nError - check you file names before proceading.")

        if not inputFileExists:
            print(f"Input FITS file (",f"{file_root}{file_name}.FITS", ") does not exist. \n")
            sys.exit()
        else:
            print("Output directory (",f"{ppxf_out_root}",") for pPXF files does not exist. \n")
            sys.exit()

    # Check n_mom is 2 or 4

    if n_mom != 2. and n_mom != 4.:
        print("Number of requested velocity moments must be 2 OR 4.")
        sys.exit()

    # Make a new pPXF fit folder at the location of ppxf_out_root for fitting plots
    try:
      os.makedirs(f"{ppxf_out_root}/pPXF_fits", exist_ok=True)
    except OSError as error:
      print("Invalid path name for output pPXF files. \n")
      sys.exit()
        
    #---------------------------------#
    # Step 1: Read in the observation #
    #---------------------------------#

    hdu = fits.open(f"{file_root}{file_name}.FITS")

    cube     = hdu["DATA"].data
    head_obs = hdu["DATA"].header
    var      = hdu["STAT"].data*1e40
    
    npart    = hdu["NPART"].data
    npart_flat = npart.reshape(-1)
    npart_flat[npart_flat == 0] = None

    hdu.close()
    
    print(f"Reading spectral cube of size {cube.shape}.")

    # Reshape the cube into an array
    npix = cube.shape[0]
    nspec = cube.shape[1] * cube.shape[2]
    spectrum = cube.reshape(npix, -1) # create an array of spectra [npix, (sbin_x * sbin_y)]
    noise_flat = var.reshape(npix, -1) 

    print(f"Re-shaping cube into array of shape {spectrum.shape}, with {spectrum.shape[0]} wavelengths and {spectrum.shape[1]} pixels.")
    print(f"Re-shaping noise into array of shape {noise_flat.shape}, with {noise_flat.shape[0]} wavelengths and {noise_flat.shape[1]} pixels.")

    # Begin by pulling out the wavelength axis of the cube -------------------------------------------------------------
    # These properties are necessary for logarithmically re-binning the spectra before
    # fitting with pPXF.
    wave_axis = head_obs['CRVAL3'] + (np.arange(0., (head_obs['NAXIS3']))*head_obs['CDELT3'])
    wave_range = head_obs["CRVAL3"] + np.array([0., head_obs["CDELT3"]*(head_obs["NAXIS3"]-1)])
    velscale = c * np.diff(np.log(wave_axis[-2:])) # Smallest velocity step
    velscale = velscale[0]
    
    print(f"CRVAL3: {head_obs['CRVAL3']}, CRDELT3: {head_obs['CDELT3']} and NAXIS3:{head_obs['NAXIS3']}")

    print(f"The velocity scale of the `observed` spectrum is {velscale} km/s per pixel.")

    # We also need to bring the observed spectrum back to the rest-frame ------------------------------------
    if z >= 0.0:
        wave_range = wave_range / (1 + z)
        FWHM_gal = FWHM_gal / (1 + z)
        z = 0
        print(f"The wavelength range of the 'observed' galaxy (returned to rest-frame) is {wave_range} Angstrom.")
        print(f"The FWHM at this restframe is {FWHM_gal}.")

    else:
        print(f"The wavelength range of the 'observed' galaxy is {wave_range} Angstrom.")
        print(f"The FWHM of the observation is {FWHM_gal}.")

    #---------------------------------#
    # Step 2: Read in the templates   #
    #---------------------------------#
    # Next, load the templates necessary to perform the fit with pPXF

    # Using pPXF function to read in the templates located at `template_loc`, this
    # function reads each template spectrum into an array sorted by age and metallicity.
    # If the FWHM_gal is larger than the FWHM_temp, this function will also convolve
    # the templates down to the same resolution as the observations.

    print(f"The FWHM of the templates is {FWHM_temp}.")
    if FWHM_gal <= FWHM_temp:
        FWHM_gal = None
        FWHM_temp = None
        print(f"No convolution can be made. Setting FWHM_gal, FWHM_temp = None.")

    miles = lib.miles(pathname = template_loc, velscale = velscale, FWHM_gal = FWHM_gal, FWHM_tem = FWHM_temp, norm_range=[5000, 5950])

    templates = miles.templates
    stars_templates = templates.reshape(templates.shape[0], -1)
    stars_templates /= np.median(stars_templates) # Normalizes stellar templates by a scalar

    log_lam_temp = miles.ln_lam_temp
    #reg_dim = miles.templates.shape[1:]
    #regul_err = 0.013  # Desired regularization error

    mask = (np.exp(log_lam_temp) > (np.min(wave_range)-500)) & (np.exp(log_lam_temp) < (np.max(wave_range)+500))

    log_lam_temp = log_lam_temp[mask]
    stars_templates = stars_templates[mask]

    wave_range_temp =[np.exp(np.min(log_lam_temp)), np.exp(np.max(log_lam_temp))]

    print(f"The wavelength range of the template spectra is {wave_range_temp} Angstrom.")
    print(f"Array of templates containing shape {stars_templates.shape}.")

    #----------------------------------------#
    # Step 3: Fitting the observed spectra   #
    #----------------------------------------#

    # Preparing the galaxy observations for input into pPXF
    galaxy, log_lam_galaxy, velscale = util.log_rebin(wave_range, spectrum[:,11], velscale=velscale)
    galaxy /= np.median(galaxy)

    dv = (log_lam_temp[0] - log_lam_galaxy[0])*c
    vel = c*np.log(1 + z)
    start = [vel, 200.] # starting guess for kinematic measurements

    print(f"The starting guess velocity, as according to Cappellari 2017 [V = c*log(1 + z)] is {vel} km/s.")

    # Now fitting each pixel in turn and comparing to the LOS_VEL and LOS_DISP values ----------------------------------
    if n_mom == 2:
        ppxf_velocity    = np.empty_like(npart_flat)
        ppxf_dispersion  = np.empty_like(npart_flat)
        ppxf_chi2        = np.empty_like(npart_flat)
    else:
        ppxf_velocity    = np.empty_like(npart_flat)
        ppxf_dispersion  = np.empty_like(npart_flat)
        ppxf_h3          = np.empty_like(npart_flat)
        ppxf_h4          = np.empty_like(npart_flat)
        ppxf_chi2        = np.empty_like(npart_flat)

    print(f"The 'observed' spectrum has a staring wavelength of {log_lam_galaxy[0]} Angstrom.")
    print(f"The template spectrum has a staring wavelength of {log_lam_temp[0]} Angstrom.")
    print(f"The difference is therefore {dv} km/s.")

    for j in range(nspec):
        if npart_flat[j] > 0:
            print(f"Fitting pixel [{j}]...")
            galaxy, log_lam_galaxy, velscale = util.log_rebin(wave_range, spectrum[:,j], velscale=velscale)
            noise_rebin, log_lam_noise, velscale_2 = util.log_rebin(wave_range, 1/np.sqrt(noise_flat[:,j]), velscale=velscale)
            noise_rebin /= np.median(galaxy)
            galaxy /= np.median(galaxy)
            
            if n_mom == 2:
                pp = ppxf(stars_templates, galaxy, noise_rebin, velscale, start,
                          vsyst=dv, lam = np.exp(log_lam_galaxy),
                          plot=False, moments=2, degree=-1, mdegree=7,  # Set plot to False when using in batch mode. change mdegree=10 for testing
                          clean=False, regul=False)
                ppxf_velocity[j]   = pp.sol[0]
                ppxf_dispersion[j] = pp.sol[1]
                ppxf_chi2[j]       = pp.chi2

                if plot:
                  pp.plot()
                  plt.savefig(f"{ppxf_out_root}/pPXF_fits/pPXF_fit_{j}.png")
                  plt.close()

            else:
                pp = ppxf(stars_templates, galaxy, noise_rebin, velscale, start,
                          vsyst=dv, lam = np.exp(log_lam_galaxy), 
                          plot=False, moments=4, degree=-1, mdegree=7,  # Set plot to False when using in batch mode. change mdegree=10 for testing
                          clean=False, regul=False)
                
                ppxf_velocity[j]   = pp.sol[0]
                ppxf_dispersion[j] = pp.sol[1]
                ppxf_h3[j]         = pp.sol[2]
                ppxf_h4[j]         = pp.sol[3]
                ppxf_chi2[j]       = pp.chi2

                if plot:
                  pp.plot()
                  plt.savefig(f"{ppxf_out_root}/pPXF_fits/pPXF_fit_{j}.png")
                  plt.close()


        else:
            if n_mom == 2:
                print(f"Pixel [{j}] is empty, proceading to next one...")
                ppxf_velocity[j]   = np.nan
                ppxf_dispersion[j] = np.nan
                ppxf_chi2[j]       = np.nan

            else:
                print(f"Pixel [{j}] is empty, proceading to next one...")
                ppxf_velocity[j]   = np.nan
                ppxf_dispersion[j] = np.nan
                ppxf_h3[j]         = np.nan
                ppxf_h4[j]         = np.nan
                ppxf_chi2[j]       = np.nan

    # --------------------------------- #
    # Step 4: Reshaping the fit results #
    #         back to images            #
    # --------------------------------- #

    fit_velocity   = ppxf_velocity.reshape([cube.shape[1], cube.shape[2]])
    fit_dispersion = ppxf_dispersion.reshape([cube.shape[1], cube.shape[2]])
    fit_chi2       = ppxf_chi2.reshape([cube.shape[1], cube.shape[2]])

    np.save(f"{ppxf_out_root}{file_name}_ppxf_velocity.npy", fit_velocity)
    np.save(f"{ppxf_out_root}{file_name}_ppxf_dispersion.npy", fit_dispersion)
    np.save(f"{ppxf_out_root}{file_name}_ppxf_chi2.npy", fit_chi2)

    if n_mom == 4:

        fit_h3 = ppxf_h3.reshape([cube.shape[1], cube.shape[2]])
        fit_h4 = ppxf_h4.reshape([cube.shape[1], cube.shape[2]])
        np.save(f"{ppxf_out_root}{file_name}_ppxf_h3.npy", fit_h3)
        np.save(f"{ppxf_out_root}{file_name}_ppxf_h4.npy", fit_h4)
        
    print(f"Done with the {i} iteration.")
    del cube, galaxy, noise_rebin, var, head_obs
# Out:
# Reading spectral cube of size (1924, 30, 30).
# Re-shaping cube into array of shape (1924, 900), with 1924 wavelengths and 900 pixels.
# Re-shaping noise into array of shape (1924, 900), with 1924 wavelengths and 900 pixels.
# CRVAL3: 3750, CRDELT3: 1.04 and NAXIS3:1924
# The velocity scale of the `observed` spectrum is 54.228990358951044 km/s per pixel.
# The wavelength range of the 'observed' galaxy (returned to rest-frame) is [3696.76656151 5668.29652997] Angstrom.
# The FWHM at this restframe is 2.51.
# The FWHM of the templates is 2.51.
# No convolution can be made. Setting FWHM_gal, FWHM_temp = None.
# The wavelength range of the template spectra is [3196.81691845587, 6167.683415503795] Angstrom.
# Array of templates containing shape (3634, 258).
# The starting guess velocity, as according to Cappellari 2017 [V = c*log(1 + z)] is 0.0 km/s.
# The 'observed' spectrum has a staring wavelength of 8.215165582202367 Angstrom.
# The template spectrum has a staring wavelength of 8.06991088075 Angstrom.
# The difference is therefore -43546.26398446149 km/s.
# Pixel [0] is empty, proceading to next one...
# Pixel [1] is empty, proceading to next one...
# Pixel [2] is empty, proceading to next one...
# Pixel [3] is empty, proceading to next one...
# Pixel [4] is empty, proceading to next one...
# Pixel [5] is empty, proceading to next one...
# Pixel [6] is empty, proceading to next one...
# Pixel [7] is empty, proceading to next one...
# Pixel [8] is empty, proceading to next one...
# Pixel [9] is empty, proceading to next one...
# Pixel [10] is empty, proceading to next one...
# Fitting pixel [11]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -2       100    -0.003    -0.025
# chi2/DOF: 1.021; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 13; Func calls: 161; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [12]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -16        61     0.048     0.300
# chi2/DOF: 1.063; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 126; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [13]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        69    -0.004     0.300
# chi2/DOF: 0.9218; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 88; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [14]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -2        89    -0.080     0.029
# chi2/DOF: 0.9355; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [15]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14        86     0.009     0.066
# chi2/DOF: 0.9128; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [16]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -1        98    -0.020    -0.006
# chi2/DOF: 0.9391; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 13; Func calls: 161; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [17]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -15        90    -0.009     0.046
# chi2/DOF: 1.247; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 137; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [18]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9       100    -0.001    -0.014
# chi2/DOF: 0.9924; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 99; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Pixel [19] is empty, proceading to next one...
# Pixel [20] is empty, proceading to next one...
# Pixel [21] is empty, proceading to next one...
# Pixel [22] is empty, proceading to next one...
# Pixel [23] is empty, proceading to next one...
# Pixel [24] is empty, proceading to next one...
# Pixel [25] is empty, proceading to next one...
# Pixel [26] is empty, proceading to next one...
# Pixel [27] is empty, proceading to next one...
# Pixel [28] is empty, proceading to next one...
# Pixel [29] is empty, proceading to next one...
# Pixel [30] is empty, proceading to next one...
# Pixel [31] is empty, proceading to next one...
# Pixel [32] is empty, proceading to next one...
# Pixel [33] is empty, proceading to next one...
# Pixel [34] is empty, proceading to next one...
# Pixel [35] is empty, proceading to next one...
# Pixel [36] is empty, proceading to next one...
# Pixel [37] is empty, proceading to next one...
# Fitting pixel [38]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -4        90    -0.014     0.053
# chi2/DOF: 0.9454; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [39]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -17        93     0.010     0.018
# chi2/DOF: 0.9001; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 90; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [40]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8       101    -0.011     0.006
# chi2/DOF: 0.8959; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 116; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [41]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8        98     0.009     0.001
# chi2/DOF: 0.8968; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 90; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [42]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -19       103     0.008    -0.065
# chi2/DOF: 1.362; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 13; Func calls: 161; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [43]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -19        97    -0.020     0.007
# chi2/DOF: 0.9801; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/258
# Fitting pixel [44]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -17       103    -0.011    -0.013
# chi2/DOF: 0.9671; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 115; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [45]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -12       102    -0.019    -0.024
# chi2/DOF: 1.126; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 149; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [46]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14       102    -0.011    -0.010
# chi2/DOF: 0.9588; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 14; Func calls: 174; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [47]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14        81     0.069     0.106
# chi2/DOF: 0.9118; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 136; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [48]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:         1        99     0.038     0.017
# chi2/DOF: 0.8484; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/258
# Fitting pixel [49]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14       105     0.002    -0.029
# chi2/DOF: 0.8840; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 102; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [50]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -15       105     0.045    -0.024
# chi2/DOF: 1.033; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 135; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [51]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -12        88    -0.018     0.004
# chi2/DOF: 0.8667; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 90; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Pixel [52] is empty, proceading to next one...
# Pixel [53] is empty, proceading to next one...
# Pixel [54] is empty, proceading to next one...
# Pixel [55] is empty, proceading to next one...
# Pixel [56] is empty, proceading to next one...
# Pixel [57] is empty, proceading to next one...
# Pixel [58] is empty, proceading to next one...
# Pixel [59] is empty, proceading to next one...
# Pixel [60] is empty, proceading to next one...
# Pixel [61] is empty, proceading to next one...
# Pixel [62] is empty, proceading to next one...
# Pixel [63] is empty, proceading to next one...
# Pixel [64] is empty, proceading to next one...
# Pixel [65] is empty, proceading to next one...
# Pixel [66] is empty, proceading to next one...
# Fitting pixel [67]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -7        93    -0.009    -0.011
# chi2/DOF: 0.8959; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [68]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -17        94     0.057     0.022
# chi2/DOF: 1.014; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 99; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [69]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -5        68    -0.082     0.300
# chi2/DOF: 0.9298; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [70]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -12        87    -0.013     0.059
# chi2/DOF: 0.8864; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [71]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14        94    -0.008     0.031
# chi2/DOF: 0.9553; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 138; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/258
# Fitting pixel [72]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -2        89    -0.059     0.034
# chi2/DOF: 0.8703; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [73]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -20        97     0.015     0.011
# chi2/DOF: 1.013; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 139; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [74]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -19        95     0.012    -0.038
# chi2/DOF: 0.9235; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [75]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -16        79    -0.003     0.106
# chi2/DOF: 0.9632; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 150; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [76]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -21        98    -0.000    -0.022
# chi2/DOF: 0.9041; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [77]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -7        81     0.016     0.058
# chi2/DOF: 0.8536; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [78]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9        86     0.003     0.097
# chi2/DOF: 0.9691; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 102; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [79]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10        96    -0.035    -0.002
# chi2/DOF: 1.203; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 103; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [80]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -15        89     0.015     0.065
# chi2/DOF: 0.9010; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [81]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -4        97    -0.007     0.013
# chi2/DOF: 0.8631; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 110; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [82]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9        96     0.016     0.037
# chi2/DOF: 0.9905; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Pixel [83] is empty, proceading to next one...
# Pixel [84] is empty, proceading to next one...
# Pixel [85] is empty, proceading to next one...
# Pixel [86] is empty, proceading to next one...
# Pixel [87] is empty, proceading to next one...
# Pixel [88] is empty, proceading to next one...
# Pixel [89] is empty, proceading to next one...
# Pixel [90] is empty, proceading to next one...
# Pixel [91] is empty, proceading to next one...
# Pixel [92] is empty, proceading to next one...
# Pixel [93] is empty, proceading to next one...
# Pixel [94] is empty, proceading to next one...
# Fitting pixel [95]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -21        94     0.040     0.006
# chi2/DOF: 0.8971; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 110; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [96]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9        96    -0.035    -0.001
# chi2/DOF: 0.9975; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 135; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [97]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9        64    -0.122     0.300
# chi2/DOF: 1.018; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 115; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [98]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -1        88    -0.028     0.039
# chi2/DOF: 0.9971; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 136; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [99]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        87    -0.013     0.037
# chi2/DOF: 0.9647; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/258
# Fitting pixel [100]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -13        80     0.013     0.110
# chi2/DOF: 0.9145; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 138; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [101]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9        59     0.010     0.264
# chi2/DOF: 1.019; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 14; Func calls: 172; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [102]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:         1        88    -0.053     0.028
# chi2/DOF: 1.196; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 135; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/258
# Fitting pixel [103]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -5        73    -0.045     0.138
# chi2/DOF: 1.148; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [104]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -19        64     0.122     0.300
# chi2/DOF: 1.109; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [105]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -5        93     0.003     0.000
# chi2/DOF: 0.9181; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 113; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [106]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14        91     0.022     0.019
# chi2/DOF: 0.9271; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [107]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -3        76    -0.043     0.131
# chi2/DOF: 1.078; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 102; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [108]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -15        97     0.002     0.020
# chi2/DOF: 1.087; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 115; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [109]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -6        88     0.002     0.038
# chi2/DOF: 0.9143; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [110]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -12        93     0.038    -0.000
# chi2/DOF: 0.9615; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 138; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [111]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -25        64     0.162     0.204
# chi2/DOF: 0.9908; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 15; Func calls: 187; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [112]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -2        96    -0.021    -0.010
# chi2/DOF: 0.9283; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 116; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [113]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -19       106    -0.003    -0.032
# chi2/DOF: 0.9169; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 102; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [114]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -3        91    -0.073     0.056
# chi2/DOF: 0.9707; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Pixel [115] is empty, proceading to next one...
# Pixel [116] is empty, proceading to next one...
# Pixel [117] is empty, proceading to next one...
# Pixel [118] is empty, proceading to next one...
# Pixel [119] is empty, proceading to next one...
# Pixel [120] is empty, proceading to next one...
# Pixel [121] is empty, proceading to next one...
# Pixel [122] is empty, proceading to next one...
# Pixel [123] is empty, proceading to next one...
# Fitting pixel [124]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -0       107    -0.002    -0.009
# chi2/DOF: 0.9117; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 135; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [125]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -12        97     0.018     0.014
# chi2/DOF: 0.9049; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [126]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9        94    -0.015    -0.001
# chi2/DOF: 0.9016; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 149; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [127]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        87     0.051     0.034
# chi2/DOF: 0.8488; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [128]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -27        79     0.148     0.124
# chi2/DOF: 0.9503; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 116; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [129]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10        96    -0.040     0.028
# chi2/DOF: 0.9475; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [130]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -5        99     0.024     0.014
# chi2/DOF: 0.9057; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [131]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9        65    -0.097     0.255
# chi2/DOF: 1.037; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 17; Func calls: 211; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [132]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -6        82    -0.017     0.094
# chi2/DOF: 1.113; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 21; Func calls: 260; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [133]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8        89    -0.045     0.036
# chi2/DOF: 1.123; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 126; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/258
# Fitting pixel [134]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8        94    -0.027     0.005
# chi2/DOF: 0.9496; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [135]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -3        97    -0.016    -0.025
# chi2/DOF: 1.180; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 112; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [136]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        88     0.004     0.067
# chi2/DOF: 0.9863; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [137]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -7        62     0.055     0.300
# chi2/DOF: 0.9395; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [138]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -6        94    -0.081    -0.016
# chi2/DOF: 1.197; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 150; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [139]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10       101    -0.002    -0.016
# chi2/DOF: 1.120; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 14; Func calls: 175; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [140]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -7       100    -0.004    -0.031
# chi2/DOF: 1.330; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 113; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [141]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -18        93     0.031    -0.002
# chi2/DOF: 0.8840; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 110; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [142]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -7        62     0.004     0.241
# chi2/DOF: 0.9510; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 149; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [143]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -20        90     0.073    -0.011
# chi2/DOF: 1.042; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 149; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [144]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -5        58     0.026     0.300
# chi2/DOF: 0.9739; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 13; Func calls: 163; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/258
# Fitting pixel [145]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9       107    -0.048    -0.010
# chi2/DOF: 0.8752; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 90; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Pixel [146] is empty, proceading to next one...
# Pixel [147] is empty, proceading to next one...
# Pixel [148] is empty, proceading to next one...
# Pixel [149] is empty, proceading to next one...
# Pixel [150] is empty, proceading to next one...
# Pixel [151] is empty, proceading to next one...
# Pixel [152] is empty, proceading to next one...
# Fitting pixel [153]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -2        79     0.002     0.105
# chi2/DOF: 0.8945; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 126; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [154]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -6        82    -0.004     0.070
# chi2/DOF: 0.8869; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 13; Func calls: 162; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [155]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8       104    -0.019    -0.035
# chi2/DOF: 0.9554; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 146; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [156]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -1        95    -0.007     0.030
# chi2/DOF: 0.8797; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [157]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -16        92    -0.031    -0.012
# chi2/DOF: 0.9248; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [158]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -23        87     0.089     0.068
# chi2/DOF: 1.104; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 115; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [159]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -4        97    -0.012    -0.012
# chi2/DOF: 0.9627; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [160]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -2        91    -0.032    -0.019
# chi2/DOF: 0.9360; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [161]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -27        93     0.037    -0.032
# chi2/DOF: 1.069; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 15; Func calls: 183; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [162]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:         1        94    -0.065     0.004
# chi2/DOF: 0.9648; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [163]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8        94    -0.046     0.032
# chi2/DOF: 1.069; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [164]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14        87    -0.036     0.018
# chi2/DOF: 1.063; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [165]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -6        94    -0.010    -0.004
# chi2/DOF: 1.079; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 80; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [166]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -12        94     0.012     0.013
# chi2/DOF: 0.9160; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [167]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -5        62    -0.078     0.300
# chi2/DOF: 0.9886; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [168]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10        87    -0.007     0.043
# chi2/DOF: 0.9079; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 88; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [169]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -17        58     0.051     0.300
# chi2/DOF: 1.068; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 116; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [170]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -18        59    -0.038     0.300
# chi2/DOF: 1.962; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 152; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [171]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -22        94     0.051     0.048
# chi2/DOF: 0.9121; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 112; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/258
# Fitting pixel [172]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -5        88     0.034     0.022
# chi2/DOF: 0.9718; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 110; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [173]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -19        65     0.114     0.300
# chi2/DOF: 1.048; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 139; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [174]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:         1        94     0.011     0.005
# chi2/DOF: 0.8828; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 5; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [175]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -16       103     0.009    -0.051
# chi2/DOF: 0.9439; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [176]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -21        84     0.031     0.153
# chi2/DOF: 1.103; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 103; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Pixel [177] is empty, proceading to next one...
# Pixel [178] is empty, proceading to next one...
# Pixel [179] is empty, proceading to next one...
# Pixel [180] is empty, proceading to next one...
# Pixel [181] is empty, proceading to next one...
# Pixel [182] is empty, proceading to next one...
# Fitting pixel [183]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -0        97    -0.025     0.028
# chi2/DOF: 0.8873; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [184]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -15        96    -0.018    -0.015
# chi2/DOF: 0.9918; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 13; Func calls: 163; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/258
# Fitting pixel [185]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -13        96    -0.014    -0.016
# chi2/DOF: 0.8715; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [186]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9        63    -0.002     0.300
# chi2/DOF: 0.9708; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [187]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -26        64     0.153     0.300
# chi2/DOF: 1.129; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 137; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [188]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -18        83    -0.015     0.001
# chi2/DOF: 0.9016; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 101; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [189]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -4       100     0.002    -0.019
# chi2/DOF: 1.116; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [190]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -16        60     0.093     0.300
# chi2/DOF: 0.9660; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 81; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [191]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -7        86     0.036     0.042
# chi2/DOF: 1.176; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 15; Func calls: 185; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [192]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -19        82     0.049     0.064
# chi2/DOF: 1.072; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 100; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [193]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -17        89    -0.008     0.040
# chi2/DOF: 1.058; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [194]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -6        83    -0.028     0.035
# chi2/DOF: 1.197; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 141; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/258
# Fitting pixel [195]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -7        98    -0.007    -0.009
# chi2/DOF: 1.187; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 115; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [196]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -19        68     0.064     0.278
# chi2/DOF: 1.006; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [197]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -12        88     0.012     0.021
# chi2/DOF: 1.020; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 20; Func calls: 245; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [198]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:         1        78    -0.056     0.111
# chi2/DOF: 0.9993; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 112; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [199]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -16        83     0.028     0.061
# chi2/DOF: 0.9250; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [200]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        66     0.021     0.237
# chi2/DOF: 1.174; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 138; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [201]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:         6        84    -0.092    -0.007
# chi2/DOF: 1.320; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 14; Func calls: 173; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [202]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -2        80    -0.005     0.060
# chi2/DOF: 1.076; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 136; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [203]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:         5        71    -0.180     0.226
# chi2/DOF: 0.9372; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 89; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [204]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -2       109     0.000    -0.038
# chi2/DOF: 0.8718; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [205]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -3        64    -0.036     0.237
# chi2/DOF: 1.081; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 101; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [206]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -19        89    -0.017     0.066
# chi2/DOF: 0.9123; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 90; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Pixel [207] is empty, proceading to next one...
# Pixel [208] is empty, proceading to next one...
# Pixel [209] is empty, proceading to next one...
# Pixel [210] is empty, proceading to next one...
# Pixel [211] is empty, proceading to next one...
# Fitting pixel [212]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14        65    -0.006     0.222
# chi2/DOF: 1.111; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 15; Func calls: 184; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [213]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10        96     0.017     0.034
# chi2/DOF: 0.9020; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 146; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [214]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -1        77    -0.039     0.154
# chi2/DOF: 0.9540; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 103; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/258
# Fitting pixel [215]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14        77     0.044     0.098
# chi2/DOF: 0.8567; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [216]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14        63     0.065     0.300
# chi2/DOF: 1.017; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 116; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [217]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -7        85    -0.045     0.053
# chi2/DOF: 0.9713; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 19; Func calls: 240; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [218]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -13        97     0.020    -0.005
# chi2/DOF: 0.9137; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [219]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -15       103     0.019    -0.037
# chi2/DOF: 2.903; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 20; Func calls: 249; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [220]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        92    -0.019     0.009
# chi2/DOF: 1.222; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/258
# Fitting pixel [221]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -12        88     0.034     0.022
# chi2/DOF: 1.151; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 127; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/258
# Fitting pixel [222]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -7        62    -0.028     0.300
# chi2/DOF: 1.013; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/258
# Fitting pixel [223]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -21        61     0.177     0.300
# chi2/DOF: 1.102; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 116; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [224]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -9        80     0.010     0.102
# chi2/DOF: 0.9948; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 113; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [225]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        63     0.008     0.286
# chi2/DOF: 1.007; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 19; Func calls: 232; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [226]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -2        92    -0.006     0.051
# chi2/DOF: 1.196; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 113; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [227]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -13        92     0.039     0.033
# chi2/DOF: 0.9307; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 101; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [228]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:         1        87    -0.077     0.034
# chi2/DOF: 1.323; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 16; Func calls: 199; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/258
# Fitting pixel [229]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -7        95     0.063    -0.005
# chi2/DOF: 0.9466; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# ...
#  comp.  0:       -19        85     0.035     0.024
# chi2/DOF: 0.9181; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 136; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [364]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        92     0.033     0.027
# chi2/DOF: 1.006; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 13; Func calls: 160; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [365]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -23        77     0.003     0.039
# chi2/DOF: 1.321; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 115; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [366]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10        89     0.005    -0.025
# chi2/DOF: 1.106; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 90; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [367]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10        90    -0.008     0.000
# chi2/DOF: 1.214; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [368]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -15        63    -0.006     0.213
# chi2/DOF: 1.259; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/258
# Fitting pixel [369]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -12        89     0.015    -0.008
# chi2/DOF: 1.292; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 17; Func calls: 211; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [370]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8        77    -0.007     0.064
# chi2/DOF: 1.021; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [371]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        81    -0.012     0.021
# chi2/DOF: 1.720; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 138; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [372]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8        54     0.032     0.300
# chi2/DOF: 1.279; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 113; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [373]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10        85    -0.009    -0.003
# chi2/DOF: 1.341; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 14; Func calls: 173; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [374]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -14        67     0.052     0.088
# chi2/DOF: 1.307; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 137; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [375]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -4        55    -0.026     0.293
# chi2/DOF: 1.764; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 146; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/258
# Fitting pixel [376]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -23        57     0.182     0.300
# chi2/DOF: 1.367; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 115; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [377]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10        75     0.004     0.037
# chi2/DOF: 1.470; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 15; Func calls: 182; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [378]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -16        68     0.083     0.141
# chi2/DOF: 1.212; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 103; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/258
# Fitting pixel [379]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -12        78    -0.014     0.089
# chi2/DOF: 1.195; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 15; Func calls: 182; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [380]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10        67    -0.016     0.119
# chi2/DOF: 1.120; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [381]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -16        63     0.044     0.300
# chi2/DOF: 1.123; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 12; Func calls: 146; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [382]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8        86    -0.033     0.017
# chi2/DOF: 1.103; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 13; Func calls: 162; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [383]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -19        95     0.020    -0.014
# chi2/DOF: 0.9658; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 126; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [384]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        84     0.024     0.056
# chi2/DOF: 1.231; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/258
# Fitting pixel [385]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -15        92     0.048    -0.007
# chi2/DOF: 0.9781; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/258
# Fitting pixel [386]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -11        95    -0.005     0.035
# chi2/DOF: 0.8641; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 110; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [387]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -4        85     0.006     0.043
# chi2/DOF: 0.9826; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 113; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [388]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -1        79    -0.018     0.147
# chi2/DOF: 0.9750; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 112; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [389]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -10        88    -0.010     0.039
# chi2/DOF: 0.8856; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [390]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -16        98     0.012     0.026
# chi2/DOF: 1.061; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [391]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -1        99    -0.045    -0.027
# chi2/DOF: 1.038; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/258
# Fitting pixel [392]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -27        92     0.039     0.031
# chi2/DOF: 1.315; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 14; Func calls: 173; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [393]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -6        65    -0.057     0.273
# chi2/DOF: 0.9168; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 6; Func calls: 80; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [394]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -6       100     0.042    -0.008
# chi2/DOF: 0.9086; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 8; Func calls: 103; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/258
# Fitting pixel [395]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -13        71    -0.030     0.206
# chi2/DOF: 1.058; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/258
# Fitting pixel [396]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -6        91    -0.018     0.005
# chi2/DOF: 1.062; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/258
# Fitting pixel [397]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8        85     0.000     0.073
# chi2/DOF: 1.196; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 7; Func calls: 90; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [398]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -8        62    -0.025     0.299
# chi2/DOF: 1.531; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 11; Func calls: 136; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/258
# Fitting pixel [399]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       -28        53     0.185     0.300
# chi2/DOF: 1.592; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 9; Func calls: 116; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [400]...
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:        -6        72    -0.023     0.077
# chi2/DOF: 0.9774; DOF: 2353; degree = -1; mdegree = 7
# method = capfit; Jac calls: 10; Func calls: 127; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/258
# Fitting pixel [401]...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <module>
#     183       plt.close()
#     185 else:
# --> 186     pp = ppxf(stars_templates, galaxy, noise_rebin, velscale, start,
#     187               vsyst=dv, lam = np.exp(log_lam_galaxy),
#     188               plot=False, moments=4, degree=-1, mdegree=7,  # Set plot to False when using in batch mode. change mdegree=10 for testing
#     189               clean=False, regul=False)
#     191     ppxf_velocity[j]   = pp.sol[0]
#     192     ppxf_dispersion[j] = pp.sol[1]
#
# File ~/.pyenv/versions/3.9.6/envs/SimSpin/lib/python3.9/site-packages/ppxf/ppxf.py:1862, in ppxf.__init__(self, templates, galaxy, noise, velscale, start, bias, bounds, clean, component, constr_templ, constr_kinem, degree, fixed, fraction, ftol, gas_component, gas_names, gas_reddening, global_search, goodpixels, lam, lam_temp, linear, linear_method, mask, method, mdegree, moments, phot, plot, quiet, reddening, reddening_func, reg_dim, reg_ord, regul, sigma_diff, sky, templates_rfft, tied, trig, velscale_ratio, vsyst, x0)
#    1860     self.njev = 0     # Jacobian is not evaluated
#    1861 else:
# -> 1862     params, perror = self.nonlinear_fit(start1, bounds, fixed, tied, clean)
#    1864 self.bias = 0   # Evaluate residuals without bias
#    1865 err = self.linear_fit(params)
#
# File ~/.pyenv/versions/3.9.6/envs/SimSpin/lib/python3.9/site-packages/ppxf/ppxf.py:2072, in ppxf.nonlinear_fit(self, start0, bounds0, fixed0, tied0, clean)
#    2070 self.clean = False  # No cleaning during chi2 optimization
#    2071 if self.method == 'capfit':
# -> 2072     res = capfit(
#    2073         self.linear_fit, start, ftol=self.ftol, bounds=bounds.T,
#    2074         abs_step=step, x_scale='jac', tied=tied, fixed=fixed,
#    2075         A_ineq=self.A_ineq_kinem, b_ineq=self.b_ineq_kinem,
#    2076         A_eq=self.A_eq_kinem, b_eq=self.b_eq_kinem)
#    2077     perror = res.x_err
#    2078 else:
#
# File ~/.pyenv/versions/3.9.6/envs/SimSpin/lib/python3.9/site-packages/ppxf/capfit.py:845, in capfit.__init__(self, func, p0, A_eq, A_ineq, abs_step, b_eq, b_ineq, bounds, diff_step, fixed, ftol, linear_method, max_nfev, rcond, tied, verbose, x_scale, xtol, args, kwargs)
#     841     assert np.all(np.isfinite(resid)), \
#     842         "The fitting function returned infinite residuals"
#     843     return resid
# --> 845 p1, p1_err = self.optimize(call, p0[free], A_eq, b_eq, A_ineq, b_ineq, bounds[:, free])
#     847 self.x = tie(p1)
#     848 self.x_err = np.zeros_like(self.x)
#
# File ~/.pyenv/versions/3.9.6/envs/SimSpin/lib/python3.9/site-packages/ppxf/capfit.py:919, in capfit.optimize(self, call, p1, A_eq, b_eq, A_ineq, b_ineq, bounds)
#     916         lam /= 2
#     918     if ratio > 0.01:  # Successful step: move on
# --> 919         J2 = self.fdjac(call, p2, f2, bounds)
#     920         p1, f1, J1 = p2, f2, J2
#     922 self.cost = 0.5*chi2(f1)  # as in least_squares()
#
# File ~/.pyenv/versions/3.9.6/envs/SimSpin/lib/python3.9/site-packages/ppxf/capfit.py:961, in capfit.fdjac(self, call, pars, f, bounds)
#     959     pars1 = pars.copy()
#     960     pars1[j] += hj
# --> 961     f1 = call(pars1)
#     962     jac[:, j] = (f1 - f)/hj
#     964 return jac
#
# File ~/.pyenv/versions/3.9.6/envs/SimSpin/lib/python3.9/site-packages/ppxf/capfit.py:840, in capfit.__init__.<locals>.call(pfree)
#     838 self.nfev += 1
#     839 p = tie(pfree)
# --> 840 resid = func(p, *args, **kwargs)
#     841 assert np.all(np.isfinite(resid)), \
#     842     "The fitting function returned infinite residuals"
#     843 return resid
#
# File ~/.pyenv/versions/3.9.6/envs/SimSpin/lib/python3.9/site-packages/ppxf/ppxf.py:2138, in ppxf.linear_fit(self, pars)
#    2136 for j, template_rfft in enumerate(self.templates_rfft.T):  # loop over column templates
#    2137     for k in range(nspec):
# -> 2138         tt = np.fft.irfft(template_rfft*lvd_rfft[:, self.component[j], k], self.npad)
#    2139         tmp[k, :] = rebin(tt[:self.npix*self.velscale_ratio], self.velscale_ratio)
#    2140     c[: nrows_spec, npoly + j] = tmp.ravel()
#
# File <__array_function__ internals>:180, in irfft(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.6/envs/SimSpin/lib/python3.9/site-packages/numpy/fft/_pocketfft.py:513, in irfft(a, n, axis, norm)
#     511     n = (a.shape[axis] - 1) * 2
#     512 inv_norm = _get_backward_norm(n, norm)
# --> 513 output = _raw_fft(a, n, axis, True, False, inv_norm)
#     514 return output
#
# File ~/.pyenv/versions/3.9.6/envs/SimSpin/lib/python3.9/site-packages/numpy/fft/_pocketfft.py:70, in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      67         a = z
#      69 if axis == a.ndim-1:
# ---> 70     r = pfi.execute(a, is_real, is_forward, fct)
#      71 else:
#      72     a = swapaxes(a, axis, -1)
#
# KeyboardInterrupt:
